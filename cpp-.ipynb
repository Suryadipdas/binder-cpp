// %% [markdown]
// # cout

// %%
#include <iostream>
using namespace std;

// %%
cout <<"hello"<<endl;
// Out:
// hello

// %%
cout <<"hello"<<endl;
cout <<"sexy"<<flush;
cout <<" girl"<<endl;
// Out:
// hello
// sexy girl

// %%
cout<<"hello"<<endl<<"sexy"<<" girl"<<endl;
// Out:
// hello
// sexy girl

// %% [markdown]
// # Variables

// %%
int chumu = 377377

// %%
int nunu

// %%
nunu   //default value is 0
// Out:
// 0

// %%
nunu==0
// Out:
// input_line_30:2:6: note: use '=' to turn this equality comparison into an assignment
//  nunu==0
//      ^~
//      =
// true

// %%
double pusu= 439290984.9832753289;
pusu
// Out:
// 4.3929098e+08

// %%
int amma=10;
int appa=20;
amma+appa
// Out:
// 30
